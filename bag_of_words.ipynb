# %% [markdown]
# <a href="https://colab.research.google.com/github/nitin-khandagale/machine_learning_practice/blob/master/bag_of_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import re

# %%
link = "https://www.hopefully.live/post/data-analysis-of-campus-placement-data"

# %%
import requests

# %%
urlc = requests.get(link)

# %%
soup = BeautifulSoup(urlc.content, 'html5')

# %%
div = soup.find_all('p')

# %%
para_data = []

for p in range(len(div)):
  para_data.append(div[p].get_text())

# %%
new_data = ''.join(para_data)
new_data
# Out:
# "Data Analysis is nothing but the telling a story through data. I am going to extract some useful information from campus placement data.You can download the data from here.I also tried answering questions asked on this data from kaggle. let's find out answers to these questionsWhich factor influenced a candidate in getting placed?Does percentage matters for one to get placed?Which degree specialization is much demanded by corporate?Play with the data conducting all statistical tests.I will first Explore the data through some charts then will get back to these questions.Lets have look at our dataStatus is target variable here which depends upon other independent feature. First column contains the genders of the candidates. Lets see the distribution of genders.Data has two Genders Males and Females out of which, more than 67% are males and 35% are female. But what is the distribution of Gender with respect to Placement Status ?The percentage of placement among males and females. Percentage of placed males is more than double of Non Placed and placed female candidates while Percentage of placed females is slightly less than double of Non Placed females candidates.All the candidates categorized according to stream they have chosen in Higher Secondary class. Lets see which stream placed highest number of candidates.Commerce and Science streams dominates this chart. Arts has lowest number of placements. This data helps Different departments to work on things which can give their stream better placements.Let's see the same distribution on degree college.Comm&Mgmt streamers placed in large numbers. This data reflects same patterns as Higher Secondary distribution as Commerce stream dominates in both.Data also has score percentages of different classes. Lets see the average percentage of placed candidates and non placed candidates.SSC class has the highest difference between average scores followed by HSC , degree and MBA percentage. There not much difference between average marks of placed and non placed candidates in MBA class which implies that placements aren't solely depends on marks but the other factors as well.Big chunk of our candidates has same previous experience. Lets see if that helps them in placements.Oddly it seems that previous experience of candidates isn't that affecting the their placements as more number non experienced candidates are placed than experienced one.Other than all these, does extra specialization matter in placements ? lets seeSkills in Marketing and finance does matter it seems.  More candidates of Mkt&Fin are placed than Mkt&HR.This information will help the institutions to work on their not so good fields. Many educational institutes performs such kind of analysis now days.Let's get back the questions and answer them one by one.1. Which factor influenced a candidate in getting placed?     Using RandomForestClassifier one can get most important features which affect the results by feature_importances_  method. Lets see what i found in our data.ssc_p is affecting the placement status the most. So, Answer is SSC marks helps candidates to get placements.2. Does percentage matters for one to get placed ?One can perform few pandas operations to get this answer but answer to the previous question answers this question too in disguise. If look closely, most important features which affects the result are all related to the percentage of different classes. Answer is Yes !3. Which degree specialization is much demanded by corporate ?I This question is already answered above where 'Placement by Specialization' chart is  showed. Lets have a lookAnswer is Mkt&Fin degree specialization is more demanded !I did this analysis using python and Plotly. You can get code of above practice hereDo share your suggestion through any one of the ways mentioned at the bottom of the page.Thank you.Thanks for submitting!"

# %%
new_data = re.sub('\W+', ' ', new_data)
new_data = re.sub('\d+', ' ', new_data)

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
words = word_tokenize(new_data)

# %%
words
# Out:
# ['Data',
#  'Analysis',
#  'is',
#  'nothing',
#  'but',
#  'the',
#  'telling',
#  'a',
#  'story',
#  'through',
#  'data',
#  'I',
#  'am',
#  'going',
#  'to',
#  'extract',
#  'some',
#  'useful',
#  'information',
#  'from',
#  'campus',
#  'placement',
#  'data',
#  'You',
#  'can',
#  'download',
#  'the',
#  'data',
#  'from',
#  'here',
#  'I',
#  'also',
#  'tried',
#  'answering',
#  'questions',
#  'asked',
#  'on',
#  'this',
#  'data',
#  'from',
#  'kaggle',
#  'let',
#  's',
#  'find',
#  'out',
#  'answers',
#  'to',
#  'these',
#  'questionsWhich',
#  'factor',
#  'influenced',
#  'a',
#  'candidate',
#  'in',
#  'getting',
#  'placed',
#  'Does',
#  'percentage',
#  'matters',
#  'for',
#  'one',
#  'to',
#  'get',
#  'placed',
#  'Which',
#  'degree',
#  'specialization',
#  'is',
#  'much',
#  'demanded',
#  'by',
#  'corporate',
#  'Play',
#  'with',
#  'the',
#  'data',
#  'conducting',
#  'all',
#  'statistical',
#  'tests',
#  'I',
#  'will',
#  'first',
#  'Explore',
#  'the',
#  'data',
#  'through',
#  'some',
#  'charts',
#  'then',
#  'will',
#  'get',
#  'back',
#  'to',
#  'these',
#  'questions',
#  'Lets',
#  'have',
#  'look',
#  'at',
#  'our',
#  'dataStatus',
#  'is',
#  'target',
#  'variable',
#  'here',
#  'which',
#  'depends',
#  'upon',
#  'other',
#  'independent',
#  'feature',
#  'First',
#  'column',
#  'contains',
#  'the',
#  'genders',
#  'of',
#  'the',
#  'candidates',
#  'Lets',
#  'see',
#  'the',
#  'distribution',
#  'of',
#  'genders',
#  'Data',
#  'has',
#  'two',
#  'Genders',
#  'Males',
#  'and',
#  'Females',
#  'out',
#  'of',
#  'which',
#  'more',
#  'than',
#  'are',
#  'males',
#  'and',
#  'are',
#  'female',
#  'But',
#  'what',
#  'is',
#  'the',
#  'distribution',
#  'of',
#  'Gender',
#  'with',
#  'respect',
#  'to',
#  'Placement',
#  'Status',
#  'The',
#  'percentage',
#  'of',
#  'placement',
#  'among',
#  'males',
#  'and',
#  'females',
#  'Percentage',
#  'of',
#  'placed',
#  'males',
#  'is',
#  'more',
#  'than',
#  'double',
#  'of',
#  'Non',
#  'Placed',
#  'and',
#  'placed',
#  'female',
#  'candidates',
#  'while',
#  'Percentage',
#  'of',
#  'placed',
#  'females',
#  'is',
#  'slightly',
#  'less',
#  'than',
#  'double',
#  'of',
#  'Non',
#  'Placed',
#  'females',
#  'candidates',
#  'All',
#  'the',
#  'candidates',
#  'categorized',
#  'according',
#  'to',
#  'stream',
#  'they',
#  'have',
#  'chosen',
#  'in',
#  'Higher',
#  'Secondary',
#  'class',
#  'Lets',
#  'see',
#  'which',
#  'stream',
#  'placed',
#  'highest',
#  'number',
#  'of',
#  'candidates',
#  'Commerce',
#  'and',
#  'Science',
#  'streams',
#  'dominates',
#  'this',
#  'chart',
#  'Arts',
#  'has',
#  'lowest',
#  'number',
#  'of',
#  'placements',
#  'This',
#  'data',
#  'helps',
#  'Different',
#  'departments',
#  'to',
#  'work',
#  'on',
#  'things',
#  'which',
#  'can',
#  'give',
#  'their',
#  'stream',
#  'better',
#  'placements',
#  'Let',
#  's',
#  'see',
#  'the',
#  'same',
#  'distribution',
#  'on',
#  'degree',
#  'college',
#  'Comm',
#  'Mgmt',
#  'streamers',
#  'placed',
#  'in',
#  'large',
#  'numbers',
#  'This',
#  'data',
#  'reflects',
#  'same',
#  'patterns',
#  'as',
#  'Higher',
#  'Secondary',
#  'distribution',
#  'as',
#  'Commerce',
#  'stream',
#  'dominates',
#  'in',
#  'both',
#  'Data',
#  'also',
#  'has',
#  'score',
#  'percentages',
#  'of',
#  'different',
#  'classes',
#  'Lets',
#  'see',
#  'the',
#  'average',
#  'percentage',
#  'of',
#  'placed',
#  'candidates',
#  'and',
#  'non',
#  'placed',
#  'candidates',
#  'SSC',
#  'class',
#  'has',
#  'the',
#  'highest',
#  'difference',
#  'between',
#  'average',
#  'scores',
#  'followed',
#  'by',
#  'HSC',
#  'degree',
#  'and',
#  'MBA',
#  'percentage',
#  'There',
#  'not',
#  'much',
#  'difference',
#  'between',
#  'average',
#  'marks',
#  'of',
#  'placed',
#  'and',
#  'non',
#  'placed',
#  'candidates',
#  'in',
#  'MBA',
#  'class',
#  'which',
#  'implies',
#  'that',
#  'placements',
#  'aren',
#  't',
#  'solely',
#  'depends',
#  'on',
#  'marks',
#  'but',
#  'the',
#  'other',
#  'factors',
#  'as',
#  'well',
#  'Big',
#  'chunk',
#  'of',
#  'our',
#  'candidates',
#  'has',
#  'same',
#  'previous',
#  'experience',
#  'Lets',
#  'see',
#  'if',
#  'that',
#  'helps',
#  'them',
#  'in',
#  'placements',
#  'Oddly',
#  'it',
#  'seems',
#  'that',
#  'previous',
#  'experience',
#  'of',
#  'candidates',
#  'isn',
#  't',
#  'that',
#  'affecting',
#  'the',
#  'their',
#  'placements',
#  'as',
#  'more',
#  'number',
#  'non',
#  'experienced',
#  'candidates',
#  'are',
#  'placed',
#  'than',
#  'experienced',
#  'one',
#  'Other',
#  'than',
#  'all',
#  'these',
#  'does',
#  'extra',
#  'specialization',
#  'matter',
#  'in',
#  'placements',
#  'lets',
#  'seeSkills',
#  'in',
#  'Marketing',
#  'and',
#  'finance',
#  'does',
#  'matter',
#  'it',
#  'seems',
#  'More',
#  'candidates',
#  'of',
#  'Mkt',
#  'Fin',
#  'are',
#  'placed',
#  'than',
#  'Mkt',
#  'HR',
#  'This',
#  'information',
#  'will',
#  'help',
#  'the',
#  'institutions',
#  'to',
#  'work',
#  'on',
#  'their',
#  'not',
#  'so',
#  'good',
#  'fields',
#  'Many',
#  'educational',
#  'institutes',
#  'performs',
#  'such',
#  'kind',
#  'of',
#  'analysis',
#  'now',
#  'days',
#  'Let',
#  's',
#  'get',
#  'back',
#  'the',
#  'questions',
#  'and',
#  'answer',
#  'them',
#  'one',
#  'by',
#  'one',
#  'Which',
#  'factor',
#  'influenced',
#  'a',
#  'candidate',
#  'in',
#  'getting',
#  'placed',
#  'Using',
#  'RandomForestClassifier',
#  'one',
#  'can',
#  'get',
#  'most',
#  'important',
#  'features',
#  'which',
#  'affect',
#  'the',
#  'results',
#  'by',
#  'feature_importances_',
#  'method',
#  'Lets',
#  'see',
#  'what',
#  'i',
#  'found',
#  'in',
#  'our',
#  'data',
#  'ssc_p',
#  'is',
#  'affecting',
#  'the',
#  'placement',
#  'status',
#  'the',
#  'most',
#  'So',
#  'Answer',
#  'is',
#  'SSC',
#  'marks',
#  'helps',
#  'candidates',
#  'to',
#  'get',
#  'placements',
#  'Does',
#  'percentage',
#  'matters',
#  'for',
#  'one',
#  'to',
#  'get',
#  'placed',
#  'One',
#  'can',
#  'perform',
#  'few',
#  'pandas',
#  'operations',
#  'to',
#  'get',
#  'this',
#  'answer',
#  'but',
#  'answer',
#  'to',
#  'the',
#  'previous',
#  'question',
#  'answers',
#  'this',
#  'question',
#  'too',
#  'in',
#  'disguise',
#  'If',
#  'look',
#  'closely',
#  'most',
#  'important',
#  'features',
#  'which',
#  'affects',
#  'the',
#  'result',
#  'are',
#  'all',
#  'related',
#  'to',
#  'the',
#  'percentage',
#  'of',
#  'different',
#  'classes',
#  'Answer',
#  'is',
#  'Yes',
#  'Which',
#  'degree',
#  'specialization',
#  'is',
#  'much',
#  'demanded',
#  'by',
#  'corporate',
#  'I',
#  'This',
#  'question',
#  'is',
#  'already',
#  'answered',
#  'above',
#  'where',
#  'Placement',
#  'by',
#  'Specialization',
#  'chart',
#  'is',
#  'showed',
#  'Lets',
#  'have',
#  'a',
#  'lookAnswer',
#  'is',
#  'Mkt',
#  'Fin',
#  'degree',
#  'specialization',
#  'is',
#  'more',
#  'demanded',
#  'I',
#  'did',
#  'this',
#  'analysis',
#  'using',
#  'python',
#  'and',
#  'Plotly',
#  'You',
#  'can',
#  'get',
#  'code',
#  'of',
#  'above',
#  'practice',
#  'hereDo',
#  'share',
#  'your',
#  'suggestion',
#  'through',
#  'any',
#  'one',
#  'of',
#  'the',
#  'ways',
#  'mentioned',
#  'at',
#  'the',
#  'bottom',
#  'of',
#  'the',
#  'page',
#  'Thank',
#  'you',
#  'Thanks',
#  'for',
#  'submitting']

# %%
len(words)
# Out:
# 625

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
cleaned_words = [word for word in words if not word in stop_words]

# %%
cleaned_words
# Out:
# ['Data',
#  'Analysis',
#  'nothing',
#  'telling',
#  'story',
#  'data',
#  'I',
#  'going',
#  'extract',
#  'useful',
#  'information',
#  'campus',
#  'placement',
#  'data',
#  'You',
#  'download',
#  'data',
#  'I',
#  'also',
#  'tried',
#  'answering',
#  'questions',
#  'asked',
#  'data',
#  'kaggle',
#  'let',
#  'find',
#  'answers',
#  'questionsWhich',
#  'factor',
#  'influenced',
#  'candidate',
#  'getting',
#  'placed',
#  'Does',
#  'percentage',
#  'matters',
#  'one',
#  'get',
#  'placed',
#  'Which',
#  'degree',
#  'specialization',
#  'much',
#  'demanded',
#  'corporate',
#  'Play',
#  'data',
#  'conducting',
#  'statistical',
#  'tests',
#  'I',
#  'first',
#  'Explore',
#  'data',
#  'charts',
#  'get',
#  'back',
#  'questions',
#  'Lets',
#  'look',
#  'dataStatus',
#  'target',
#  'variable',
#  'depends',
#  'upon',
#  'independent',
#  'feature',
#  'First',
#  'column',
#  'contains',
#  'genders',
#  'candidates',
#  'Lets',
#  'see',
#  'distribution',
#  'genders',
#  'Data',
#  'two',
#  'Genders',
#  'Males',
#  'Females',
#  'males',
#  'female',
#  'But',
#  'distribution',
#  'Gender',
#  'respect',
#  'Placement',
#  'Status',
#  'The',
#  'percentage',
#  'placement',
#  'among',
#  'males',
#  'females',
#  'Percentage',
#  'placed',
#  'males',
#  'double',
#  'Non',
#  'Placed',
#  'placed',
#  'female',
#  'candidates',
#  'Percentage',
#  'placed',
#  'females',
#  'slightly',
#  'less',
#  'double',
#  'Non',
#  'Placed',
#  'females',
#  'candidates',
#  'All',
#  'candidates',
#  'categorized',
#  'according',
#  'stream',
#  'chosen',
#  'Higher',
#  'Secondary',
#  'class',
#  'Lets',
#  'see',
#  'stream',
#  'placed',
#  'highest',
#  'number',
#  'candidates',
#  'Commerce',
#  'Science',
#  'streams',
#  'dominates',
#  'chart',
#  'Arts',
#  'lowest',
#  'number',
#  'placements',
#  'This',
#  'data',
#  'helps',
#  'Different',
#  'departments',
#  'work',
#  'things',
#  'give',
#  'stream',
#  'better',
#  'placements',
#  'Let',
#  'see',
#  'distribution',
#  'degree',
#  'college',
#  'Comm',
#  'Mgmt',
#  'streamers',
#  'placed',
#  'large',
#  'numbers',
#  'This',
#  'data',
#  'reflects',
#  'patterns',
#  'Higher',
#  'Secondary',
#  'distribution',
#  'Commerce',
#  'stream',
#  'dominates',
#  'Data',
#  'also',
#  'score',
#  'percentages',
#  'different',
#  'classes',
#  'Lets',
#  'see',
#  'average',
#  'percentage',
#  'placed',
#  'candidates',
#  'non',
#  'placed',
#  'candidates',
#  'SSC',
#  'class',
#  'highest',
#  'difference',
#  'average',
#  'scores',
#  'followed',
#  'HSC',
#  'degree',
#  'MBA',
#  'percentage',
#  'There',
#  'much',
#  'difference',
#  'average',
#  'marks',
#  'placed',
#  'non',
#  'placed',
#  'candidates',
#  'MBA',
#  'class',
#  'implies',
#  'placements',
#  'solely',
#  'depends',
#  'marks',
#  'factors',
#  'well',
#  'Big',
#  'chunk',
#  'candidates',
#  'previous',
#  'experience',
#  'Lets',
#  'see',
#  'helps',
#  'placements',
#  'Oddly',
#  'seems',
#  'previous',
#  'experience',
#  'candidates',
#  'affecting',
#  'placements',
#  'number',
#  'non',
#  'experienced',
#  'candidates',
#  'placed',
#  'experienced',
#  'one',
#  'Other',
#  'extra',
#  'specialization',
#  'matter',
#  'placements',
#  'lets',
#  'seeSkills',
#  'Marketing',
#  'finance',
#  'matter',
#  'seems',
#  'More',
#  'candidates',
#  'Mkt',
#  'Fin',
#  'placed',
#  'Mkt',
#  'HR',
#  'This',
#  'information',
#  'help',
#  'institutions',
#  'work',
#  'good',
#  'fields',
#  'Many',
#  'educational',
#  'institutes',
#  'performs',
#  'kind',
#  'analysis',
#  'days',
#  'Let',
#  'get',
#  'back',
#  'questions',
#  'answer',
#  'one',
#  'one',
#  'Which',
#  'factor',
#  'influenced',
#  'candidate',
#  'getting',
#  'placed',
#  'Using',
#  'RandomForestClassifier',
#  'one',
#  'get',
#  'important',
#  'features',
#  'affect',
#  'results',
#  'feature_importances_',
#  'method',
#  'Lets',
#  'see',
#  'found',
#  'data',
#  'ssc_p',
#  'affecting',
#  'placement',
#  'status',
#  'So',
#  'Answer',
#  'SSC',
#  'marks',
#  'helps',
#  'candidates',
#  'get',
#  'placements',
#  'Does',
#  'percentage',
#  'matters',
#  'one',
#  'get',
#  'placed',
#  'One',
#  'perform',
#  'pandas',
#  'operations',
#  'get',
#  'answer',
#  'answer',
#  'previous',
#  'question',
#  'answers',
#  'question',
#  'disguise',
#  'If',
#  'look',
#  'closely',
#  'important',
#  'features',
#  'affects',
#  'result',
#  'related',
#  'percentage',
#  'different',
#  'classes',
#  'Answer',
#  'Yes',
#  'Which',
#  'degree',
#  'specialization',
#  'much',
#  'demanded',
#  'corporate',
#  'I',
#  'This',
#  'question',
#  'already',
#  'answered',
#  'Placement',
#  'Specialization',
#  'chart',
#  'showed',
#  'Lets',
#  'lookAnswer',
#  'Mkt',
#  'Fin',
#  'degree',
#  'specialization',
#  'demanded',
#  'I',
#  'analysis',
#  'using',
#  'python',
#  'Plotly',
#  'You',
#  'get',
#  'code',
#  'practice',
#  'hereDo',
#  'share',
#  'suggestion',
#  'one',
#  'ways',
#  'mentioned',
#  'bottom',
#  'page',
#  'Thank',
#  'Thanks',
#  'submitting']

# %%
len(cleaned_words)
# Out:
# 383

# %%
for word in cleaned_words:
  word

# %%
word_count = {}

for w in cleaned_words:
  if w not in word_count.keys():
    word_count[w] = 1
  else:
    word_count[w] += 1

# %%
word_count
# Out:
# {'All': 1,
#  'Analysis': 1,
#  'Answer': 2,
#  'Arts': 1,
#  'Big': 1,
#  'But': 1,
#  'Comm': 1,
#  'Commerce': 2,
#  'Data': 3,
#  'Different': 1,
#  'Does': 2,
#  'Explore': 1,
#  'Females': 1,
#  'Fin': 2,
#  'First': 1,
#  'Gender': 1,
#  'Genders': 1,
#  'HR': 1,
#  'HSC': 1,
#  'Higher': 2,
#  'I': 5,
#  'If': 1,
#  'Let': 2,
#  'Lets': 7,
#  'MBA': 2,
#  'Males': 1,
#  'Many': 1,
#  'Marketing': 1,
#  'Mgmt': 1,
#  'Mkt': 3,
#  'More': 1,
#  'Non': 2,
#  'Oddly': 1,
#  'One': 1,
#  'Other': 1,
#  'Percentage': 2,
#  'Placed': 2,
#  'Placement': 2,
#  'Play': 1,
#  'Plotly': 1,
#  'RandomForestClassifier': 1,
#  'SSC': 2,
#  'Science': 1,
#  'Secondary': 2,
#  'So': 1,
#  'Specialization': 1,
#  'Status': 1,
#  'Thank': 1,
#  'Thanks': 1,
#  'The': 1,
#  'There': 1,
#  'This': 4,
#  'Using': 1,
#  'Which': 3,
#  'Yes': 1,
#  'You': 2,
#  'according': 1,
#  'affect': 1,
#  'affecting': 2,
#  'affects': 1,
#  'already': 1,
#  'also': 2,
#  'among': 1,
#  'analysis': 2,
#  'answer': 3,
#  'answered': 1,
#  'answering': 1,
#  'answers': 2,
#  'asked': 1,
#  'average': 3,
#  'back': 2,
#  'better': 1,
#  'bottom': 1,
#  'campus': 1,
#  'candidate': 2,
#  'candidates': 13,
#  'categorized': 1,
#  'chart': 2,
#  'charts': 1,
#  'chosen': 1,
#  'chunk': 1,
#  'class': 3,
#  'classes': 2,
#  'closely': 1,
#  'code': 1,
#  'college': 1,
#  'column': 1,
#  'conducting': 1,
#  'contains': 1,
#  'corporate': 2,
#  'data': 9,
#  'dataStatus': 1,
#  'days': 1,
#  'degree': 5,
#  'demanded': 3,
#  'departments': 1,
#  'depends': 2,
#  'difference': 2,
#  'different': 2,
#  'disguise': 1,
#  'distribution': 4,
#  'dominates': 2,
#  'double': 2,
#  'download': 1,
#  'educational': 1,
#  'experience': 2,
#  'experienced': 2,
#  'extra': 1,
#  'extract': 1,
#  'factor': 2,
#  'factors': 1,
#  'feature': 1,
#  'feature_importances_': 1,
#  'features': 2,
#  'female': 2,
#  'females': 3,
#  'fields': 1,
#  'finance': 1,
#  'find': 1,
#  'first': 1,
#  'followed': 1,
#  'found': 1,
#  'genders': 2,
#  'get': 8,
#  'getting': 2,
#  'give': 1,
#  'going': 1,
#  'good': 1,
#  'help': 1,
#  'helps': 3,
#  'hereDo': 1,
#  'highest': 2,
#  'implies': 1,
#  'important': 2,
#  'independent': 1,
#  'influenced': 2,
#  'information': 2,
#  'institutes': 1,
#  'institutions': 1,
#  'kaggle': 1,
#  'kind': 1,
#  'large': 1,
#  'less': 1,
#  'let': 1,
#  'lets': 1,
#  'look': 2,
#  'lookAnswer': 1,
#  'lowest': 1,
#  'males': 3,
#  'marks': 3,
#  'matter': 2,
#  'matters': 2,
#  'mentioned': 1,
#  'method': 1,
#  'much': 3,
#  'non': 3,
#  'nothing': 1,
#  'number': 3,
#  'numbers': 1,
#  'one': 7,
#  'operations': 1,
#  'page': 1,
#  'pandas': 1,
#  'patterns': 1,
#  'percentage': 6,
#  'percentages': 1,
#  'perform': 1,
#  'performs': 1,
#  'placed': 15,
#  'placement': 3,
#  'placements': 7,
#  'practice': 1,
#  'previous': 3,
#  'python': 1,
#  'question': 3,
#  'questions': 3,
#  'questionsWhich': 1,
#  'reflects': 1,
#  'related': 1,
#  'respect': 1,
#  'result': 1,
#  'results': 1,
#  'score': 1,
#  'scores': 1,
#  'see': 6,
#  'seeSkills': 1,
#  'seems': 2,
#  'share': 1,
#  'showed': 1,
#  'slightly': 1,
#  'solely': 1,
#  'specialization': 4,
#  'ssc_p': 1,
#  'statistical': 1,
#  'status': 1,
#  'story': 1,
#  'stream': 4,
#  'streamers': 1,
#  'streams': 1,
#  'submitting': 1,
#  'suggestion': 1,
#  'target': 1,
#  'telling': 1,
#  'tests': 1,
#  'things': 1,
#  'tried': 1,
#  'two': 1,
#  'upon': 1,
#  'useful': 1,
#  'using': 1,
#  'variable': 1,
#  'ways': 1,
#  'well': 1,
#  'work': 2}

# %%
import heapq

top = heapq.nlargest(20, word_count, key=word_count.get)

# %%
top_counts = []
for u in top:
  top_counts.append(word_count[u])

# %%
top_counts
# Out:
# [15, 13, 9, 8, 7, 7, 7, 6, 6, 5, 5, 4, 4, 4, 4, 3, 3, 3, 3, 3]

# %%
import plotly.express as px

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure([go.Bar(x=top, y=top_counts, marker_color = px.colors.qualitative.D3)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="db5c7f37-60ce-4f47-b6e4-d88a4f4150ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db5c7f37-60ce-4f47-b6e4-d88a4f4150ef")) {
#                     Plotly.newPlot(
#                         'db5c7f37-60ce-4f47-b6e4-d88a4f4150ef',
#                         [{"marker": {"color": ["#1F77B4", "#FF7F0E", "#2CA02C", "#D62728", "#9467BD", "#8C564B", "#E377C2", "#7F7F7F", "#BCBD22", "#17BECF"]}, "type": "bar", "x": ["placed", "candidates", "data", "get", "one", "Lets", "placements", "percentage", "see", "I", "degree", "specialization", "distribution", "stream", "This", "Data", "placement", "questions", "Which", "much"], "y": [15, 13, 9, 8, 7, 7, 7, 6, 6, 5, 5, 4, 4, 4, 4, 3, 3, 3, 3, 3]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
